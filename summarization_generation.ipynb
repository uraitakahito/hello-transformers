# %%
# !pip install transformers[ja,sentencepiece,torch]
# !pip install fugashi
# !pip install unidic_lite
from transformers import pipeline

text2text_pipeline = pipeline(model="llm-book/t5-base-long-livedoor-news-corpus")
article = """太平洋クロマグロの資源管理を協議する国際会議は3日、2025年以降の漁獲枠について30キログラム以上の大型魚は現在の1.5倍に増やすことで最終合意した。水産庁が同日公表した。資源量が回復傾向にあるためで増枠は22年以来3年ぶりとなる。

国際会議は中西部太平洋まぐろ類委員会（WCPFC）の年次会合で、11月28日からフィジーで開いた。日本や米国、太平洋の島しょ国など26カ国・地域が参加した。最終日の12月3日に全会一致で合意に達し、閉幕した。

太平洋クロマグロは刺し身や高級すしネタとして人気が高い。国内の年間供給量は養殖や輸入を含め22年時点でおよそ3万3000トンだった。日本は大幅な増枠を求め、交渉していた。

25年以降の日本の漁獲枠は大型魚で24年比2807トン増の8421トンに決まった。30キロ未満の小型魚は400トン増の4407トンで、現在の漁獲規制が始まった15年以降で初めての増枠となった。

各国全体の漁獲枠は大型魚で24年比4260トン増の1万1869トン、小型魚で400トン増の5125トンを見込む。会合では余った漁獲枠の一部を翌年に繰り越すことができる措置の恒久化や、漁獲枠を26年に見直すことも合意した。

太平洋クロマグロを巡っては乱獲の影響で減ったことを受け、15年から国際的な漁獲規制を設けた。近年は資源量が増加傾向だ。北太平洋まぐろ類国際科学委員会（ISC）によると、親魚の資源量は22年に14万4000トンと10年の12倍にまで回復した。

江藤拓農相は3日の記者会見で、会合に先立ち「（WCPFCにおいて）日本が極めて主導的な立場をとり、資源回復につながったことは素晴らしい」と評した。「漁業者がしっかりルールを守って管理し、資源回復へ協力してもらったことに感謝する」とも話した。

7月にはWCPFCなどが北海道釧路市で開いた関連会議で、増枠の措置について暫定的に合意していた。今回の会合でもその合意を維持し、最終的な決定に至った。"""
# 要約を生成
print(text2text_pipeline(article)[0]["generated_text"])
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.4/13.4 MB 50.2 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 47.4/47.4 MB 11.3 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 671.7/671.7 kB 15.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 86.8/86.8 kB 6.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 72.1/72.1 MB 7.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 50.8 MB/s eta 0:00:00
# ...
#   Created wheel for ipadic: filename=ipadic-1.0.0-py3-none-any.whl size=13556704 sha256=c54f7ef9184124e9f67460904897176ddadb7fb9aa8780038619a9f87ad347a5
#   Stored in directory: /root/.cache/pip/wheels/5b/ea/e3/2f6e0860a327daba3b030853fce4483ed37468bbf1101c59c3
# ...
